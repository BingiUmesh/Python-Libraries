# %% [markdown]
# ## What is Pandas?
# #### Pandas (short for "Panel Data") is a Python library used to:
# - Read, write, and clean structured data (like CSV, Excel, SQL).
# - Analyze, filter, and aggregate large datasets.
# - Perform operations similar to SQL or Excel, but programmatically.
# - Handle missing data, time series, and categorical variables.
# ##### It is built on top of NumPy and integrates well with Matplotlib, Scikit-learn, and more.

# %% [markdown]
# ### How to Install

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bingi umesh\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bingi umesh\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Core Data Structures in Pandas

# %% [markdown]
# ### 1. Series (1D)
# A one-dimensional labeled array (like a column).

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### 2. DataFrame (2D)
# A two-dimensional labeled data structure (like a table).

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'])

# %%
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# ### Exploring Data
# - df.head()         # First 5 rows
# - df.tail()         # Last 5 rows
# - df.info()         # Structure of DataFrame
# - df.describe()     # Summary statistics
# - df.shape          # Rows and columns
# - df.columns        # Column names
# - df.dtypes         # Data types
# - df.index          # Index names
# - df.size

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.size
# Out:
# 6

# %%
df.head(1)
# Out:
#    A  B  C
# 0  1  2  3

# %%
df.tail(1)
# Out:
#    A  B  C
# 2  7  8  9

# %%
df.columns
df.columns.tolist()
# Out:
# ['A', 'B', 'C']

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# dtype: object

# %%
df.size
# Out:
# 9

# %% [markdown]
# ### Selecting Data
# - df['Age']               # Select column
# - df[['Name', 'Age']]     # Select multiple columns
# - df.iloc[0]              # Select by position [rows,cols] -> Using only index values
# - df.loc[0]               # Select by index label [rows,cols]
# - df[df['Age'] > 30]      # Filter rows

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df.nunique()
# Out:
# Name    3
# Age     3
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([25, 30, 35])

# %%
df.Age
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df[['Age','Name']]
# Out:
#    Age     Name
# 0   25    Alice
# 1   30      Bob
# 2   35  Charlie

# %%
df.iloc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df[df['Age']>30]
# Out:
#       Name  Age
# 2  Charlie   35

# %% [markdown]
# ### Reading and Writing Data
#
# | Format | Function                         |
# | ------ | -------------------------------- |
# | CSV    | `pd.read_csv()` / `to_csv()`     |
# | Excel  | `pd.read_excel()` / `to_excel()` |
# | JSON   | `pd.read_json()` / `to_json()`   |
# | SQL    | `pd.read_sql()` / `to_sql()`     |

# %% [markdown]
# #### Other File Formats
# - Perquet
# - Feather
# - Csv
# - xlsv
# - excel
# - json
# - sql

# %%
coffee=pd.read_csv("./WarmUp Data/coffee.csv")

# %%
coffee.shape
# Out:
# (14, 3)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
olympics_data=pd.read_excel("./Data/olympics-data.xlsx")

# %%
olympics_data #default bio sheet
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
olympics_data.columns.tolist()
# Out:
# ['athlete_id',
#  'name',
#  'born_date',
#  'born_city',
#  'born_region',
#  'born_country',
#  'NOC',
#  'height_cm',
#  'weight_kg',
#  'died_date']

# %%
olympics_data.shape
# Out:
# (145500, 10)

# %% [markdown]
# #### Specific sheet

# %%
olympics_data2=pd.read_excel("./Data/olympics-data.xlsx", sheet_name="results")

# %%
olympics_data2 #result sheet data
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA              NaN   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA              NaN   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308403          Marián Skupek      148983  SVK              NaN   26.0  False
# 308404          Elsa Fermbäck      148984  SWE              NaN   28.0  False
# 308405          Hilma Lövblom      148985  SWE           Sweden   13.0  False
# 308406          Hilma Lövblom      148985  SWE              NaN    NaN  False
# 308407   Charlotta Säfvenberg      148986  NaN              NaN   24.0  False
#
#        medal
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 308403   NaN
# 308404   NaN
# 308405   NaN
# 308406   NaN
# 308407   NaN
#
# [308408 rows x 11 columns]

# %%
olympics_data2.columns.tolist()
# Out:
# ['year',
#  'type',
#  'discipline',
#  'event',
#  'as',
#  'athlete_id',
#  'noc',
#  'team',
#  'place',
#  'tied',
#  'medal']

# %%
olympics_data2.shape
# Out:
# (308408, 11)

# %%
olympics_data2.sample(10)
# Out:
#           year    type                        discipline  \
# 272045  2014.0  Winter             Bobsleigh (Bobsleigh)
# 41170   1996.0  Summer                           Fencing
# 261776  2016.0  Summer  Artistic Gymnastics (Gymnastics)
# 191469  1932.0  Winter           Speed Skating (Skating)
# 134057  1988.0  Summer                         Athletics
# 90625   1984.0  Summer                          Shooting
# 172660  1968.0  Winter            Alpine Skiing (Skiing)
# 249851  2008.0  Summer      Artistic Swimming (Aquatics)
# 1736    1920.0  Summer                            Tennis
# 165568  1904.0  Summer               Swimming (Aquatics)
#
#                                    event                    as  athlete_id  \
# 272045              Two, Women (Olympic)        Chelsea Valois      127436
# 41170   Sabre, Individual, Men (Olympic)  Archil Lortkipanidze       22235
# 261776              Rings, Men (Olympic)        Oleh Verniaiev      121658
# 191469       1,500 metres, Men (Olympic)        Erling Lindboe       89650
# 134057         800 metres, Men (Olympic)            Dale Jones       64349
# 90625              Skeet, Open (Olympic)    Wolfgang Trautwein       42597
# 172660           Slalom, Women (Olympic)            Judy Nagel       81905
# 249851             Team, Women (Olympic)             Becky Kim      116157
# 1736              Doubles, Men (Olympic)         Bohuslav Hykš         695
# 165568   1 mile Freestyle, Men (Olympic)      George Van Cleaf       79149
#
#         noc             team  place   tied medal
# 272045  CAN  Jenny Ciochetti   13.0  False   NaN
# 41170   GEO              NaN   36.0  False   NaN
# 261776  UKR              NaN   11.0  False   NaN
# 191469  NOR              NaN    NaN  False   NaN
# 134057  ANT              NaN    5.0  False   NaN
# 90625   FRG              NaN   29.0   True   NaN
# 172660  USA              NaN    NaN  False   NaN
# 249851  USA    United States    5.0  False   NaN
# 1736    TCH    Jaroslav Just    9.0   True   NaN
# 165568  USA              NaN    NaN  False   NaN

# %%
coffee.loc[0:4] #[rows,cols]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# ### Editing and Updating
# - df['Age'] = df['Age'] + 1          # Update column
# - df['City'] = ['NY', 'LA', 'SF']    # Add new column
# - df.drop('City', axis=1, inplace=True)  # Drop column
# - df.drop(0, axis=0, inplace=True)       # Drop row

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.loc[0:,['Day','Units Sold']]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %% [markdown]
# ### Sorting and Filtering
# df.sort_values('Age', ascending=False)
# df[(df['Age'] > 30) & (df['Name'] == 'Bob')]

# %%
coffee.sort_values("Units Sold",ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values(["Units Sold",'Coffee Type'],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
    print("\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
olympics_data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
olympics_data[olympics_data["weight_kg"]<150]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 1                2       Arnaud Boetsch  1969-04-01           Meulan
# 2                3         Jean Borotra  1898-08-13         Biarritz
# 3                4      Jacques Brugnon  1895-05-11      Paris VIIIe
# 5                6    Nicolas Chatelain  1970-01-13           Amiens
# 6                7        Patrick Chila  1969-11-27      Ris-Orangis
# ...            ...                  ...         ...              ...
# 145473      149200       Toms Andersons  1993-11-25             Rīga
# 145474      149201    Nadine Hofstetter  1994-10-21           Romoos
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
#
#                  born_region born_country          NOC  height_cm  weight_kg  \
# 1                   Yvelines          FRA       France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA       France      183.0       76.0
# 3                      Paris          FRA       France      168.0       64.0
# 5                      Somme          FRA       France      181.0       70.0
# 6                    Essonne          FRA       France      180.0       73.0
# ...                      ...          ...          ...        ...        ...
# 145473                  Rīga          LAT       Latvia      185.0       86.0
# 145474                Luzern          SUI  Switzerland      164.0       68.0
# 145495            Sverdlovsk          RUS          ROC      167.0       61.0
# 145496                Moskva          RUS          ROC      168.0       65.0
# 145497           Arkhangelsk          RUS          ROC      163.0       55.0
#
#          died_date
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 5              NaN
# 6              NaN
# ...            ...
# 145473         NaN
# 145474         NaN
# 145495         NaN
# 145496         NaN
# 145497         NaN
#
# [102028 rows x 10 columns]

# %%
olympics_data[olympics_data['name'].str.contains("Umesh",case=False)]
# Out:
#        athlete_id          name   born_date   born_city born_region  \
# 4731         4748  Umesh Maskey         NaN   Kathmandu     Bagmati
# 19796       19935   Umesh Parag  1971-08-15  Wellington  Wellington
#
#       born_country          NOC  height_cm  weight_kg died_date
# 4731           NEP        Nepal      170.0       63.0       NaN
# 19796          NZL  New Zealand      165.0       65.0       NaN

# %%
olympics_data.query('born_country=="USA" and born_city=="California"')
# Out:
#         athlete_id               name   born_date   born_city   born_region  \
# 78008        78599       Frank Jarvis  1878-08-31  California  Pennsylvania
# 119901      121743  Andrew Rutherfurd  1988-12-21  California  Pennsylvania
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 78008           USA  United States      167.0       58.0  1933-06-02
# 119901          USA        Bolivia      178.0       80.0         NaN

# %% [markdown]
# ### Adding & Deleting Columns
# df['Age'] = df['Age'] + 1          # Update column
# df['City'] = ['NY', 'LA', 'SF']    # Add new column
# df.drop('City', axis=1, inplace=True)  # Drop column
# df.drop(0, axis=0, inplace=True)       # Drop row

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price']=10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25     10
# 1     Monday       Latte          15     10
# 2    Tuesday    Espresso          30     10
# 3    Tuesday       Latte          20     10
# 4  Wednesday    Espresso          35     10
